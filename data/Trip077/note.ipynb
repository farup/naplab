# %%
import pickle

# %%
import os
import datetime

file_path = "/cluster/home/terjenf/naplab/data/Trip077/naplab_maptracker_infos.pkl"

# Get modification time
mod_time = os.path.getmtime(file_path)
print("Last Modified:", datetime.datetime.fromtimestamp(mod_time))

# Get creation time (only on Windows)
if hasattr(os, "path") and hasattr(os.path, "getctime"):
    create_time = os.path.getctime(file_path)
    print("Created:", datetime.datetime.fromtimestamp(create_time))

# %%
with open("/cluster/home/terjenf/naplab/data/Trip077/naplab_maptracker_infos.pkl", 'rb') as file:
    obj = pickle.load(file)

# %%
obj[-1]
# Out:
# {'lidar_path': '',
#  'token': '4ff780b7-969d-4613-9cf7-d97e102c2ff5',
#  'cams': {'C1_front60Single': {'extrinsics': array([[ 0.5227949 , -0.79534034, -0.3067886 , -0.30869954],
#           [-0.12358479,  0.28537119, -0.95041574,  1.60188915],
#           [ 0.8434526 ,  0.53478691,  0.05089863, -1.72725694],
#           [ 0.        ,  0.        ,  0.        ,  1.        ]]),
#    'intrinsics': [[1266.417203046554, 0.0, 816.2670197447984],
#     [0.0, 1266.417203046554, 491.50706579294757],
#     [0.0, 0.0, 1.0]],
#    'fw_coeff': [0.0,
#     166.02792470568306,
#     -80.91472047428145,
#     1863.526100073874,
#     0.0023691669378879867],
#    'bw_coeff': [0.0,
#     0.000536573003046215,
#     1.28669519483537e-08,
#     -1.43870852731265e-11,
#     3.0433934028912e-15],
#    'cx': 846.863159,
#    'cy': 670.665466,
#    'img_fpath': '/cluster/home/terjenf/naplab/data/Trip077/samples/C1_front60Single/C1_front60Single_1684740471554978.png'},
# ...
